# %% [markdown]
# # Geocoding with libraries or APIs

# %% [markdown]
# # Read in our addresses
#
# We'll never ever ever read in data like this again. But we'll do it now, because we love lists of dictionaries.
#
# - ***Tip:** If you get a file not found error, make sure the `addresses.csv` is in the same location as this Jupyter notebook. Maybe do `!pwd` to see where the notebook is!*

# %%
import csv

with open('addresses.csv') as fp:
    data = list(csv.DictReader(fp))

data
# Out:
# [{'street': '100 Ihwajang-gil',
#   'city': 'Ihwa-dong',
#   'state': 'Jongno District',
#   'postal_code': 'Seoul',
#   'country': 'South Korea'},
#  {'street': '4 Chome-1-1 Shimomeguro',
#   'city': ' Meguro City',
#   'state': 'Tokyo',
#   'postal_code': '153-0064',
#   'country': 'Japan'},
#  {'street': '1126 Green Giant Ln',
#   'city': 'Blue Earth',
#   'state': 'MN',
#   'postal_code': '56013',
#   'country': ''},
#  {'street': '7477 Hubbard Ave',
#   'city': 'Middleton',
#   'state': 'WI',
#   'postal_code': '53562',
#   'country': None},
#  {'street': 'WrocÅ‚awska 12',
#   'city': '',
#   'state': 'PoznaÅ„',
#   'postal_code': '61-838',
#   'country': 'Poland'}]

# %% [markdown]
# ## Create the full addresses
#
# Loop through the list, creating a new `address` variable that includes the street, city, state, postal code and country. For now, just print it out.
#
# - ***Tip:** You can go really really far in crafting a perfect address for each result, but you might not need to.*
# - ***Tip:** You aren't making a list of addresses! Just printing it out.*

# %%
for address in data:
    address = address['street'], address['city'], address['state'], address['postal_code'], address['country']
    print(address)
# Out:
# ('100 Ihwajang-gil', 'Ihwa-dong', 'Jongno District', 'Seoul', 'South Korea')
# ('4 Chome-1-1 Shimomeguro', ' Meguro City', 'Tokyo', '153-0064', 'Japan')
# ('1126 Green Giant Ln', 'Blue Earth', 'MN', '56013', '')
# ('7477 Hubbard Ave', 'Middleton', 'WI', '53562', None)
# ('WrocÅ‚awska 12', '', 'PoznaÅ„', '61-838', 'Poland')

# %% [markdown]
# ## Geocode the address
#
# **Copy and paste the code from above into the cell below,** it will be your starting point.
#
# At the end of this step, you should have a list of dictionaries with two new keys: **lat** and **lon**, that are the latitude and longitude of the address. Gecode the addresses using either Google's geocoding API directly or the Geocoder library. You can use my API key: `AIzaSyC6Xu4GUeKWFYXLm9GRBAnGkbVClo9HD_o`
#
# - Google geocoding API documentation: https://developers.google.com/maps/documentation/geocoding/requests-geocoding
# - Geocoder documentation: https://geocoder.readthedocs.io/
#
# **You can also try another geocoder if you'd like!** I would have liked to *demand* a different API but hey it's 1:43PM and you need this homework *now*.
#
# **Tips:**
#
# * *What order are lat and long in???*
# * *You can do this by creating 100% new list of dicts or updating the old one inside of the loop.*

# %%
# Copy and paste the code from the "Create the full addresses" section

# %%
from dotenv import load_dotenv
import os

load:dotenv()

API_KEY = os.getenv("API_KEY")

import csv

with open('addresses.csv') as fp:
    data_adresses = list(csv.DictReader(fp))

import requests

response = requests.get(f"https://maps.googleapis.com/maps/api/geocode/json?key={API_KEY}&address=100%20Ihwajang-gil%20Seoul%20")
data_seoul = response.json()

import requests

response = requests.get(f"https://maps.googleapis.com/maps/api/geocode/json?key={API_KEY}&address=4%20Chome-1-1Shimomeguro%20Tokyo%20")
data_tokyo = response.json()

import requests

response = requests.get(f"https://maps.googleapis.com/maps/api/geocode/json?key={API_KEY}&address=1126%20GreenGiantLn%20BlueEarth%20")
data_blueearth = response.json()

import requests

response = requests.get(f"https://maps.googleapis.com/maps/api/geocode/json?key={API_KEY}&address=7477%20HubbardAve%20Middleton%20")
data_middleton = response.json()

import requests

response = requests.get(f"https://maps.googleapis.com/maps/api/geocode/json?key={API_KEY}&address=12%20WrocÅ‚awska%20PoznaÅ„%20")
data_poznan = response.json()

data_adresses_new = [data_seoul, data_tokyo, data_blueearth, data_middleton, data_poznan]
data_adresses_new
# Out:
# [{'results': [{'address_components': [{'long_name': '100',
#       'short_name': '100',
#       'types': ['premise']},
#      {'long_name': 'Ihwajang-gil',
#       'short_name': 'Ihwajang-gil',
#       'types': ['political', 'sublocality', 'sublocality_level_4']},
#      {'long_name': 'Jongno District',
#       'short_name': 'Jongno District',
#       'types': ['political', 'sublocality', 'sublocality_level_1']},
#      {'long_name': 'Seoul',
#       'short_name': 'Seoul',
#       'types': ['administrative_area_level_1', 'political']},
#      {'long_name': 'South Korea',
#       'short_name': 'KR',
#       'types': ['country', 'political']},
#      {'long_name': '03088', 'short_name': '03088', 'types': ['postal_code']}],
#     'formatted_address': '100 Ihwajang-gil, Jongno District, Seoul, South Korea',
#     'geometry': {'location': {'lat': 37.5798019, 'lng': 127.0046643},
#      'location_type': 'ROOFTOP',
#      'viewport': {'northeast': {'lat': 37.5811508802915,
#        'lng': 127.0060132802915},
#       'southwest': {'lat': 37.5784529197085, 'lng': 127.0033153197085}}},
#     'place_id': 'ChIJTbeNgi6jfDUROvLcFGEHBqk',
#     'plus_code': {'compound_code': 'H2H3+WV Seoul, South Korea',
#      'global_code': '8Q99H2H3+WV'},
#     'types': ['street_address']}],
#   'status': 'OK'},
#  {'results': [{'address_components': [{'long_name': '1',
#       'short_name': '1',
#       'types': ['premise']},
#      {'long_name': '1',
#       'short_name': '1',
#       'types': ['political', 'sublocality', 'sublocality_level_4']},
#      {'long_name': '4-chōme',
#       'short_name': '4-chōme',
#       'types': ['political', 'sublocality', 'sublocality_level_3']},
#      {'long_name': 'Shimomeguro',
#       'short_name': 'Shimomeguro',
#       'types': ['political', 'sublocality', 'sublocality_level_2']},
#      {'long_name': 'Meguro City',
#       'short_name': 'Meguro City',
#       'types': ['locality', 'political']},
#      {'long_name': 'Tokyo',
#       'short_name': 'Tokyo',
#       'types': ['administrative_area_level_1', 'political']},
#      {'long_name': 'Japan',
#       'short_name': 'JP',
#       'types': ['country', 'political']},
#      {'long_name': '153-0064',
#       'short_name': '153-0064',
#       'types': ['postal_code']}],
#     'formatted_address': '4-chōme-1-1 Shimomeguro, Meguro City, Tokyo 153-0064, Japan',
#     'geometry': {'bounds': {'northeast': {'lat': 35.6317802,
#        'lng': 139.7067567},
#       'southwest': {'lat': 35.6316295, 'lng': 139.7066132}},
#      'location': {'lat': 35.6317048, 'lng': 139.706685},
#      'location_type': 'ROOFTOP',
#      'viewport': {'northeast': {'lat': 35.6330538302915,
#        'lng': 139.7080351802915},
#       'southwest': {'lat': 35.6303558697085, 'lng': 139.7053372197085}}},
#     'navigation_points': [{'location': {'latitude': 35.6317629,
#        'longitude': 139.706684}}],
#     'partial_match': True,
#     'place_id': 'ChIJvTOYiCOLGGARdxOAv9drnkg',
#     'types': ['premise', 'street_address']}],
#   'status': 'OK'},
#  {'results': [{'address_components': [{'long_name': '1126',
#       'short_name': '1126',
#       'types': ['street_number']},
#      {'long_name': 'Green Giant Lane',
#       'short_name': 'Green Giant Ln',
#       'types': ['route']},
#      {'long_name': 'Blue Earth',
#       'short_name': 'Blue Earth',
#       'types': ['locality', 'political']},
#      {'long_name': 'Faribault County',
#       'short_name': 'Faribault County',
#       'types': ['administrative_area_level_2', 'political']},
#      {'long_name': 'Minnesota',
#       'short_name': 'MN',
#       'types': ['administrative_area_level_1', 'political']},
#      {'long_name': 'United States',
#       'short_name': 'US',
#       'types': ['country', 'political']},
#      {'long_name': '56013', 'short_name': '56013', 'types': ['postal_code']}],
#     'formatted_address': '1126 Green Giant Ln, Blue Earth, MN 56013, USA',
#     'geometry': {'location': {'lat': 43.650971, 'lng': -94.09567899999999},
#      'location_type': 'ROOFTOP',
#      'viewport': {'northeast': {'lat': 43.65241238029149,
#        'lng': -94.09432251970848},
#       'southwest': {'lat': 43.64971441970849, 'lng': -94.0970204802915}}},
#     'navigation_points': [{'location': {'latitude': 43.65109289999999,
#        'longitude': -94.0956691}}],
#     'place_id': 'ChIJr1l_XW-L84cRrh4XFr-od88',
#     'plus_code': {'compound_code': 'MW23+9P Blue Earth, MN',
#      'global_code': '86M7MW23+9P'},
#     'types': ['street_address']}],
#   'status': 'OK'},
#  {'results': [{'address_components': [{'long_name': '7477',
#       'short_name': '7477',
#       'types': ['street_number']},
#      {'long_name': 'Hubbard Avenue',
#       'short_name': 'Hubbard Ave',
#       'types': ['route']},
#      {'long_name': 'Downtown',
#       'short_name': 'Downtown',
#       'types': ['neighborhood', 'political']},
#      {'long_name': 'Middleton',
#       'short_name': 'Middleton',
#       'types': ['locality', 'political']},
#      {'long_name': 'Dane County',
#       'short_name': 'Dane County',
#       'types': ['administrative_area_level_2', 'political']},
#      {'long_name': 'Wisconsin',
#       'short_name': 'WI',
#       'types': ['administrative_area_level_1', 'political']},
#      {'long_name': 'United States',
#       'short_name': 'US',
#       'types': ['country', 'political']},
#      {'long_name': '53562', 'short_name': '53562', 'types': ['postal_code']},
#      {'long_name': '3117',
#       'short_name': '3117',
#       'types': ['postal_code_suffix']}],
#     'formatted_address': '7477 Hubbard Ave, Middleton, WI 53562, USA',
#     'geometry': {'location': {'lat': 43.0952876, 'lng': -89.51123369999999},
#      'location_type': 'ROOFTOP',
#      'viewport': {'northeast': {'lat': 43.09671103029149,
#        'lng': -89.5099724697085},
#       'southwest': {'lat': 43.0940130697085, 'lng': -89.51267043029151}}},
#     'navigation_points': [{'location': {'latitude': 43.0953745,
#        'longitude': -89.51121260000001}}],
#     'partial_match': True,
#     'place_id': 'ChIJb61nRNWuB4gR56wtOsxz7zA',
#     'types': ['street_address', 'subpremise']}],
#   'status': 'OK'},
#  {'results': [{'address_components': [{'long_name': 'Poznań',
#       'short_name': 'Poznań',
#       'types': ['locality', 'political']},
#      {'long_name': 'Poznań',
#       'short_name': 'Poznań',
#       'types': ['administrative_area_level_2', 'political']},
#      {'long_name': 'Greater Poland Voivodeship',
#       'short_name': 'Greater Poland Voivodeship',
#       'types': ['administrative_area_level_1', 'political']},
#      {'long_name': 'Poland',
#       'short_name': 'PL',
#       'types': ['country', 'political']},
#      {'long_name': '62',
#       'short_name': '62',
#       'types': ['postal_code', 'postal_code_prefix']}],
#     'formatted_address': 'Poznań, Poland',
#     'geometry': {'bounds': {'northeast': {'lat': 52.50932779999999,
#        'lng': 17.0717062},
#       'southwest': {'lat': 52.2919254, 'lng': 16.7315877}},
#      'location': {'lat': 52.40567859999999, 'lng': 16.9312766},
#      'location_type': 'APPROXIMATE',
#      'viewport': {'northeast': {'lat': 52.50932779999999, 'lng': 17.0717062},
#       'southwest': {'lat': 52.2919254, 'lng': 16.7315877}}},
#     'partial_match': True,
#     'place_id': 'ChIJtwrh7NJEBEcR0b80A5gx6qQ',
#     'types': ['locality', 'political']},
#    {'address_components': [{'long_name': 'Wrocław',
#       'short_name': 'Wrocław',
#       'types': ['locality', 'political']},
#      {'long_name': 'Wrocław',
#       'short_name': 'Wrocław',
#       'types': ['administrative_area_level_2', 'political']},
#      {'long_name': 'Lower Silesian Voivodeship',
#       'short_name': 'Lower Silesian Voivodeship',
#       'types': ['administrative_area_level_1', 'political']},
#      {'long_name': 'Poland',
#       'short_name': 'PL',
#       'types': ['country', 'political']},
#      {'long_name': '51',
#       'short_name': '51',
#       'types': ['postal_code', 'postal_code_prefix']}],
#     'formatted_address': 'Wrocław, Poland',
#     'geometry': {'bounds': {'northeast': {'lat': 51.2100604,
#        'lng': 17.1762191},
#       'southwest': {'lat': 51.0426685, 'lng': 16.8073393}},
#      'location': {'lat': 51.10929480000001, 'lng': 17.0386019},
#      'location_type': 'APPROXIMATE',
#      'viewport': {'northeast': {'lat': 51.2100604, 'lng': 17.1762191},
#       'southwest': {'lat': 51.0426685, 'lng': 16.8073393}}},
#     'partial_match': True,
#     'place_id': 'ChIJv4q11MLpD0cR9eAFwq5WCbc',
#     'types': ['locality', 'political']}],
#   'status': 'OK'}]

# %% [markdown]
# ## Save the results
#
# This is so embarrassing to be doing it like this but we're doing it anyway. **Pay attention to your key names for latitude and longitude.**

# %%
import csv

with open('addresses-geocoded.csv', 'w') as fp:
    fieldnames=['street','city','state','postal_code','country','lat', 'lng']

    writer = csv.DictWriter(fp, fieldnames=fieldnames)
    writer.writeheader()
    for row in data:
        writer.writerow(row)
